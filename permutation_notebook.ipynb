# %%
import pandas as pd
import matplotlib.pyplot as plt
from permutation_code.permutation_test import perm_test
exp1_data = pd.read_csv("data/processed_data/exp1_clean.txt", sep=",")
exp12_data = pd.read_csv("data/processed_data/exp12_comb.csv")

# %% [markdown]
# Permutation tests for experiment 1.
# Fridge test smell (not ranked)

# %%
A = {"T1", "T3"}
B = {"T2", "T4"}
treatment = {"T1", "T2"}


metric = "Average Score"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp1_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")


plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: -0.6300000000000001
# p-value left: 0.4444444444444444
# p-value two-sided: 0.9206349206349206
# p-value right: 1

# %% [markdown]
# Fridge test weight (not ranked)

# %%
A = {"T1", "T3"}
B = {"T2", "T4"}
treatment = {"T1", "T2"}


metric = "Weight Delta"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp1_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")


plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: 0.3666666666666667
# p-value left: 1
# p-value two-sided: 1
# p-value right: 0.6031746031746031

# %% [markdown]
# Water test smell (not ranked)

# %%
A = {"T1", "T2"}
B = {"T3", "T4"}
treatment = {"T1", "T3"}


metric = "Average Score"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp1_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")

plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: 0.8783333333333336
# p-value left: 1
# p-value two-sided: 0.5396825396825397
# p-value right: 0.25396825396825395

# %% [markdown]
# Water test weight (not ranked)

# %%
A = {"T1", "T2"}
B = {"T3", "T4"}
treatment = {"T1", "T3"}


metric = "Weight Delta"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp1_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")

plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: 0.8666666666666663
# p-value left: 1
# p-value two-sided: 0.4126984126984127
# p-value right: 0.19047619047619047

# %% [markdown]
# Combined Data with experiment 2!
# Fridge test smell (not ranked)

# %%
A = {"T1", "T3"}
B = {"T2", "T4"}
treatment = {"T1", "T2"}


metric = "Average Score"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp12_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")


plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: -1.0149999999999997
# p-value left: 0.4683760683760684
# p-value two-sided: 0.4683760683760684
# p-value right: 1

# %% [markdown]
# Fridge test weight (not ranked)

# %%
A = {"T1", "T3"}
B = {"T2", "T4"}
treatment = {"T1", "T2"}


metric = "Weight Delta"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp12_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")


plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: -1.1400000000000001
# p-value left: 1
# p-value two-sided: 1
# p-value right: 0.6246642246642247

# %% [markdown]
# Water test smell (not ranked)

# %%
A = {"T1", "T2"}
B = {"T3", "T4"}
treatment = {"T1", "T3"}


metric = "Average Score"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp12_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")


plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: 1.4992592592592595
# p-value left: 1
# p-value two-sided: 0.03467643467643468
# p-value right: 0.03467643467643468

# %% [markdown]
# Water test weight (not ranked)

# %%
A = {"T1", "T2"}
B = {"T3", "T4"}
treatment = {"T1", "T3"}


metric = "Weight Delta"
agg_fn = "mean"

perm_data, p_left, p_two, p_right, obs_stat = perm_test(exp12_data, A, B, treatment, metric, agg_fn)

print(f"Observed Statistic: {obs_stat}")
print(f"p-value left: {p_left}")
print(f"p-value two-sided: {p_two}")
print(f"p-value right: {p_right}")


plt.hist(perm_data['diff'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(obs_stat, color='red', linestyle='--', linewidth=2, label=f'Observed Statistic = {obs_stat}')

# plt.xlabel('Value')
# plt.ylabel('Frequency')
plt.title('Histogram with Highlighted Point')
plt.legend()

plt.show()
# Out:
# Observed Statistic: 1.1222222222222218
# p-value left: 1
# p-value two-sided: 0.026862026862026864
# p-value right: 0.026862026862026864
